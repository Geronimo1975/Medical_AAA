# %%
import sentence_transformers

print(sentence_transformers.__version__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/medibot/lib/python3.10/site-packages/transformers/utils/import_utils.py:1817, in _LazyModule._get_module(self, module_name)
#    1816 try:
# -> 1817     return importlib.import_module("." + module_name, self.__name__)
#    1818 except Exception as e:
#
# File ~/anaconda3/envs/medibot/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1006, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:688, in _load_unlocked(spec)
#
# ...
